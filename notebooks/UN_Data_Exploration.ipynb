# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
gdp_df = pd.read_csv("../data/UNdata_Export_GDP.csv")

# %%
gdp_df = pd.read_csv("../data/UNdata_Export_GDP.csv")

# %%
gdp_df = pd.read_csv("../data/UNdata_Export_GDP.csv")

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN

# %%
gdp_df.head(10)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN
# 6     Afghanistan  2013  2116.465454              NaN
# 7     Afghanistan  2012  2075.491747              NaN
# 8     Afghanistan  2011  1904.559799              NaN
# 9     Afghanistan  2010  1957.029338              NaN

# %%
gdp_df[-5:]
# Out:
#      Country or Area                                      Year        Value  \
# 6865        Zimbabwe                                      1992  3054.889178
# 6866        Zimbabwe                                      1991  3426.598094
# 6867        Zimbabwe                                      1990  3324.348171
# 6868   footnoteSeqID                                  Footnote          NaN
# 6869               2  Excludes South Sudan after July 9, 2011.          NaN
#
#       Value Footnotes
# 6865              NaN
# 6866              NaN
# 6867              NaN
# 6868              NaN
# 6869              NaN

# %%
gdp_df = gdp_df[:-1]

# %%
gdp_df[-5:]
# Out:
#      Country or Area      Year        Value  Value Footnotes
# 6864        Zimbabwe      1993  3033.504852              NaN
# 6865        Zimbabwe      1992  3054.889178              NaN
# 6866        Zimbabwe      1991  3426.598094              NaN
# 6867        Zimbabwe      1990  3324.348171              NaN
# 6868   footnoteSeqID  Footnote          NaN              NaN

# %%
gdp_df = gdp_df[:-1]

# %%
gdp_df[-5:]
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %%
gdp_df = gdp_df.iloc[:, :-1]

# %%
gdp_df[-5:]
# Out:
#      Country or Area  Year        Value
# 6863        Zimbabwe  1994  3263.934978
# 6864        Zimbabwe  1993  3033.504852
# 6865        Zimbabwe  1992  3054.889178
# 6866        Zimbabwe  1991  3426.598094
# 6867        Zimbabwe  1990  3324.348171

# %%
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country', 'Year': 'Year', 'Value': 'GDP_Per_Capita'})

# %%
gdp_df[-5:]
# Out:
#        Country  Year  GDP_Per_Capita
# 6863  Zimbabwe  1994     3263.934978
# 6864  Zimbabwe  1993     3033.504852
# 6865  Zimbabwe  1992     3054.889178
# 6866  Zimbabwe  1991     3426.598094
# 6867  Zimbabwe  1990     3324.348171

# %%
gdp_df.shape
# Out:
# (6868, 3)

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6868 entries, 0 to 6867
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6868 non-null   object
#  1   Year            6868 non-null   object
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 161.1+ KB

# %%
gdp_df[-5:]
# Out:
#        Country  Year  GDP_Per_Capita
# 6863  Zimbabwe  1994     3263.934978
# 6864  Zimbabwe  1993     3033.504852
# 6865  Zimbabwe  1992     3054.889178
# 6866  Zimbabwe  1991     3426.598094
# 6867  Zimbabwe  1990     3324.348171

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6868 entries, 0 to 6867
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         6868 non-null   object
#  1   Year            6868 non-null   object
#  2   GDP_Per_Capita  6868 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 161.1+ KB

# %%
gdp_df_2014 = gdp_df[gdp_df["Year"] == '2014'].copy()
gdp_df_2014['GDP_Per_Capita_mm'] = 'A'
gdp_df_2014
gdp_df_2014['GDP_Per_Capita_mm'] = (gdp_df_2014['GDP_Per_Capita']/1000).round(1)
gdp_df_2014
# Out:
#                   Country  Year  GDP_Per_Capita  GDP_Per_Capita_mm
# 5             Afghanistan  2014     2102.385234                2.1
# 23                Albania  2014    11623.866679               11.6
# 53                Algeria  2014    11512.705405               11.5
# 83                 Angola  2014     8239.828837                8.2
# 113   Antigua and Barbuda  2014    18104.241470               18.1
# ...                   ...   ...             ...                ...
# 6727              Vietnam  2014     6098.489609                6.1
# 6757   West Bank and Gaza  2014     5967.073437                6.0
# 6783                World  2014    15189.648507               15.2
# 6813               Zambia  2014     3450.046561                3.5
# 6843             Zimbabwe  2014     2955.240287                3.0
#
# [238 rows x 4 columns]

# %%
#gdp_df_2014.hist(alpha=0.75, bins =30)
plt.hist(gdp_df_2014['GDP_Per_Capita_mm'])
plt.xlabel('GDP Per Capita ($mm)', fontweight ='bold')
plt.ylabel('Count', fontweight ='bold')
plt.title('2014 GDP Per Capita',fontweight ='bold')
#plot = sns.displot(data = gdp_df_2014, x='GDP_Per_Capita_mm', height=3.5, aspect=.75)
# Out:
# Text(0.5, 1.0, '2014 GDP Per Capita')

# %%
gdp_df_2014.head()
# Out:
#                  Country  Year  GDP_Per_Capita  GDP_Per_Capita_mm
# 5            Afghanistan  2014     2102.385234                2.1
# 23               Albania  2014    11623.866679               11.6
# 53               Algeria  2014    11512.705405               11.5
# 83                Angola  2014     8239.828837                8.2
# 113  Antigua and Barbuda  2014    18104.241470               18.1

# %%
#gdp_df_2014.hist(column = 'GDP_Per_Capita', bins =30)

# %%
print(gdp_df_2014.sort_values(by="GDP_Per_Capita", ascending=False))
# Out:
#                        Country  Year  GDP_Per_Capita  GDP_Per_Capita_mm
# 3721          Macao SAR, China  2014   156514.133850              156.5
# 3691                Luxembourg  2014   108760.916030              108.8
# 5138                     Qatar  2014    95578.416973               95.6
# 5464                 Singapore  2014    87808.663157               87.8
# 561                    Bermuda  2014    77361.104881               77.4
# ...                        ...   ...             ...                ...
# 4528                     Niger  2014     1127.615541                1.1
# 1422           Dem. Rep. Congo  2014     1029.790785                1.0
# 3781                    Malawi  2014     1027.208496                1.0
# 827                    Burundi  2014      886.235777                0.9
# 1047  Central African Republic  2014      822.610458                0.8
#
# [238 rows x 4 columns]

# %%
print(gdp_df_2014.sort_values(by="GDP_Per_Capita", ascending=True))
# Out:
#                        Country  Year  GDP_Per_Capita  GDP_Per_Capita_mm
# 1047  Central African Republic  2014      822.610458                0.8
# 827                    Burundi  2014      886.235777                0.9
# 3781                    Malawi  2014     1027.208496                1.0
# 1422           Dem. Rep. Congo  2014     1029.790785                1.0
# 4528                     Niger  2014     1127.615541                1.1
# ...                        ...   ...             ...                ...
# 561                    Bermuda  2014    77361.104881               77.4
# 5464                 Singapore  2014    87808.663157               87.8
# 5138                     Qatar  2014    95578.416973               95.6
# 3691                Luxembourg  2014   108760.916030              108.8
# 3721          Macao SAR, China  2014   156514.133850              156.5
#
# [238 rows x 4 columns]

# %%
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2019     2065.036398
# 1  Afghanistan  2018     2033.779002
# 2  Afghanistan  2017     2058.383832
# 3  Afghanistan  2016     2057.062164
# 4  Afghanistan  2015     2068.265904

# %%
gdp_df_1990_2017 = gdp_df[gdp_df['Year'].isin(['1990', '2017'])]
gdp_pivoted = gdp_df_1990_2017.pivot_table(index =['Country'], columns=['Year'], values= ['GDP_Per_Capita'])

# %%
gdp_pivoted
# Out:
#                     GDP_Per_Capita
# Year                          1990          2017
# Country
# Afghanistan                    NaN   2058.383832
# Albania                4842.734635  12811.759436
# Algeria                8746.352901  11737.409353
# Angola                 5783.429064   7310.901738
# Antigua and Barbuda   15459.551675  19840.076123
# ...                            ...           ...
# Vietnam                1673.249634   7155.745829
# West Bank and Gaza             NaN   6401.740891
# World                  9680.269697  16253.385518
# Zambia                 2190.182814   3485.005238
# Zimbabwe               3324.348171   3028.245976
#
# [238 rows x 2 columns]

# %%
print(gdp_df_1990_2017)
# Out:
#           Country  Year  GDP_Per_Capita
# 2     Afghanistan  2017     2058.383832
# 20        Albania  2017    12811.759436
# 47        Albania  1990     4842.734635
# 50        Algeria  2017    11737.409353
# 77        Algeria  1990     8746.352901
# ...           ...   ...             ...
# 6807        World  1990     9680.269697
# 6810       Zambia  2017     3485.005238
# 6837       Zambia  1990     2190.182814
# 6840     Zimbabwe  2017     3028.245976
# 6867     Zimbabwe  1990     3324.348171
#
# [445 rows x 3 columns]

# %%
gdp_df_1990_2017
# Out:
#           Country  Year  GDP_Per_Capita
# 2     Afghanistan  2017     2058.383832
# 20        Albania  2017    12811.759436
# 47        Albania  1990     4842.734635
# 50        Algeria  2017    11737.409353
# 77        Algeria  1990     8746.352901
# ...           ...   ...             ...
# 6807        World  1990     9680.269697
# 6810       Zambia  2017     3485.005238
# 6837       Zambia  1990     2190.182814
# 6840     Zimbabwe  2017     3028.245976
# 6867     Zimbabwe  1990     3324.348171
#
# [445 rows x 3 columns]

# %%
gdp_df[gdp_df['Year'].isin([1990, 2017])]
# Out:
# Empty DataFrame
# Columns: [Country, Year, GDP_Per_Capita]
# Index: []

# %%
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2019     2065.036398
# 1  Afghanistan  2018     2033.779002
# 2  Afghanistan  2017     2058.383832
# 3  Afghanistan  2016     2057.062164
# 4  Afghanistan  2015     2068.265904

# %%
gdp_df[gdp_df['Year'].isin(['1990', '2017'])]
# Out:
#           Country  Year  GDP_Per_Capita
# 2     Afghanistan  2017     2058.383832
# 20        Albania  2017    12811.759436
# 47        Albania  1990     4842.734635
# 50        Algeria  2017    11737.409353
# 77        Algeria  1990     8746.352901
# ...           ...   ...             ...
# 6807        World  1990     9680.269697
# 6810       Zambia  2017     3485.005238
# 6837       Zambia  1990     2190.182814
# 6840     Zimbabwe  2017     3028.245976
# 6867     Zimbabwe  1990     3324.348171
#
# [445 rows x 3 columns]

# %%
gdp_pivoted
# Out:
#                     GDP_Per_Capita
# Year                          1990          2017
# Country
# Afghanistan                    NaN   2058.383832
# Albania                4842.734635  12811.759436
# Algeria                8746.352901  11737.409353
# Angola                 5783.429064   7310.901738
# Antigua and Barbuda   15459.551675  19840.076123
# ...                            ...           ...
# Vietnam                1673.249634   7155.745829
# West Bank and Gaza             NaN   6401.740891
# World                  9680.269697  16253.385518
# Zambia                 2190.182814   3485.005238
# Zimbabwe               3324.348171   3028.245976
#
# [238 rows x 2 columns]

# %%
gdp_pivoted.columns
# Out:
# MultiIndex([('GDP_Per_Capita', '1990'),
#             ('GDP_Per_Capita', '2017')],
#            names=[None, 'Year'])

# %%
gdp_pivoted = pd.pivot_table(data=gdp_df_1990_2017, index =['Country'], columns=['Year'], values= 'GDP_Per_Capita')

# %%
gdp_pivoted
# Out:
# Year                         1990          2017
# Country
# Afghanistan                   NaN   2058.383832
# Albania               4842.734635  12811.759436
# Algeria               8746.352901  11737.409353
# Angola                5783.429064   7310.901738
# Antigua and Barbuda  15459.551675  19840.076123
# ...                           ...           ...
# Vietnam               1673.249634   7155.745829
# West Bank and Gaza            NaN   6401.740891
# World                 9680.269697  16253.385518
# Zambia                2190.182814   3485.005238
# Zimbabwe              3324.348171   3028.245976
#
# [238 rows x 2 columns]

# %%
gdp_pivoted['Percentage Change'] = "Percentage Change"

# %%
gdp_pivoted.head()
# Out:
# Year                         1990          2017  Percentage Change
# Country
# Afghanistan                   NaN   2058.383832  Percentage Change
# Albania               4842.734635  12811.759436  Percentage Change
# Algeria               8746.352901  11737.409353  Percentage Change
# Angola                5783.429064   7310.901738  Percentage Change
# Antigua and Barbuda  15459.551675  19840.076123  Percentage Change

# %%
gdp_pivoted['Percentage Change'] = ((gdp_pivoted['2017'] - gdp_pivoted['1990'])/gdp_pivoted['1990'])*100

# %%
gdp_pivoted.head()
# Out:
# Year                         1990          2017  Percentage Change
# Country
# Afghanistan                   NaN   2058.383832                NaN
# Albania               4842.734635  12811.759436         164.556297
# Algeria               8746.352901  11737.409353          34.197756
# Angola                5783.429064   7310.901738          26.411194
# Antigua and Barbuda  15459.551675  19840.076123          28.335391

# %%
gdp_pivoted[gdp_pivoted['Percentage Change'] < 0].count()
# Out:
# Year
# 1990                 17
# 2017                 17
# Percentage Change    17
# dtype: int64

# %%
gdp_pivoted.dropna()
# Out:
# Year                         1990          2017  Percentage Change
# Country
# Albania               4842.734635  12811.759436         164.556297
# Algeria               8746.352901  11737.409353          34.197756
# Angola                5783.429064   7310.901738          26.411194
# Antigua and Barbuda  15459.551675  19840.076123          28.335391
# Arab World            9694.667544  14555.474921          50.138980
# ...                           ...           ...                ...
# Vanuatu               2888.309393   3116.645194           7.905517
# Vietnam               1673.249634   7155.745829         327.655604
# World                 9680.269697  16253.385518          67.902197
# Zambia                2190.182814   3485.005238          59.119377
# Zimbabwe              3324.348171   3028.245976          -8.907075
#
# [207 rows x 3 columns]

# %%
gdp_pivoted_negative = gdp_pivoted[gdp_pivoted['Percentage Change'] < 0].count()
gdp_pivoted_negative
# Out:
# Year
# 1990                 17
# 2017                 17
# Percentage Change    17
# dtype: int64

# %%
gdp_pivoted['Percentage Change'].max()
# Out:
# 2068.4045610756907

# %%
gdp_pivoted[gdp_pivoted['Percentage Change']==gdp_pivoted['Percentage Change'].max()]
# Out:
# Year                      1990          2017  Percentage Change
# Country
# Equatorial Guinea  1039.985049  22551.083246        2068.404561

# %%
gdp_pivoted_top_perc_change = gdp_pivoted.sort_values('Percentage Change', ascending = False).head()

# %%
gdp_pivoted_top_perc_change
# Out:
# Year                                                1990          2017  \
# Country
# Equatorial Guinea                            1039.985049  22551.083246
# China                                        1423.896348  14344.421239
# Myanmar                                       619.645144   4739.910118
# East Asia & Pacific (excluding high income)  2173.223895  12986.322227
# East Asia & Pacific (IDA & IBRD)             2196.950288  13123.151792
#
# Year                                         Percentage Change
# Country
# Equatorial Guinea                                  2068.404561
# China                                               907.406281
# Myanmar                                             664.939443
# East Asia & Pacific (excluding high income)         497.560254
# East Asia & Pacific (IDA & IBRD)                    497.334945

# %%
gdp_eguinea= gdp_df[gdp_df["Country"].isin(["Equatorial Guinea"])]
gdp_china= gdp_df[gdp_df["Country"].isin(["China"])]
plt.plot(gdp_china['Year'], (gdp_china['GDP_Per_Capita']/1000), label='China', linestyle=':',linewidth=4)
plt.plot(gdp_eguinea['Year'], (gdp_eguinea['GDP_Per_Capita']/1000), label='Equatorial Guinea')
plt.xlabel('Year',fontweight ='bold')
plt.ylabel('GDP Per Capita($mm)', fontweight ='bold')
plt.title('GDP Per Capita for China and Equatorial Guinea',fontweight ='bold')
plt.legend(loc='upper right')
plt.xticks(rotation=90);

# %% [markdown]
# 18. Read in continents.csv contained in the data folder into a new dataframe called continents. We will be using this dataframe to add a new column to our dataset.

# %%
continents=pd.read_csv("../data/continents.csv")

# %%
continents.head()
# Out:
#   Continent      Country
# 0      Asia  Afghanistan
# 1    Europe      Albania
# 2    Africa      Algeria
# 3    Europe      Andorra
# 4    Africa       Angola

# %% [markdown]
# 19. Merge gdp_df and continents. Keep only the countries that appear in both data frames. Save the result back to gdp_df.

# %%
gdp_df=pd.merge(left = continents, 
         right = gdp_df, 
         left_on = 'Country', 
         right_on = 'Country')

# %% [markdown]
# 20. Determine the number of countries per continent. Create a bar chart showing this.

# %%
gdp_df.head()
# Out:
#   Continent      Country  Year  GDP_Per_Capita
# 0      Asia  Afghanistan  2019     2065.036398
# 1      Asia  Afghanistan  2018     2033.779002
# 2      Asia  Afghanistan  2017     2058.383832
# 3      Asia  Afghanistan  2016     2057.062164
# 4      Asia  Afghanistan  2015     2068.265904

# %%
gdp_countries_per_continent=gdp_df.groupby("Continent")["Country"].nunique()

# %%
gdp_df.groupby("Continent")["Country"].nunique().plot(kind="bar")
#num_countries_per_continent=gdp_df.groupby("Continent")["Country"].count().hist(bins=4)
#num_countries_per_continent
#plt.hist(num_countries["Continent"])
#???? 
#plt.legend 
#plt.hist(gdp_df.groupby("Continent")["Country"].count()['Continent'])
#plt.xlabel('GDP Per Capita ($mm)', fontweight ='bold')
#plt.ylabel('Count', fontweight ='bold')
#plt.title('2014 GDP Per Capita',fontweight ='bold')
# Out:
# <AxesSubplot:xlabel='Continent'>

# %% [markdown]
# 21.Create a seaborn boxplot showing GDP per capita in 2014 split out by continent. What do you notice?

# %%
#gdp_df_2014=gdp_df[gdp_df["Year"] == '2014']
#gdp_per_continent=gdp_df_2014.groupby("Continent")["GDP_Per_Capita"].sum()
#gdp_per_continent

# %%
#sns.boxplot(gdp_df_2014.groupby("Continent")["GDP_Per_Capita"].sum())

# %% [markdown]
# 22. Read in internet_use.csv into a DataFrame called internet_df. You will most likely get an error message when doing this - figure out what is going wrong and fix it. Take a look at the first and last five rows and make any corrections to your read_csv() call to fix this. Again, do not modify the original datasets.

# %%
internet_df=pd.read_csv("../data/internet_use.csv")
internet_df
# Out:
#      Country or Area    Year     Value  Value Footnotes
# 0        Afghanistan  2014.0  6.390000              NaN
# 1        Afghanistan  2013.0  5.900000              NaN
# 2        Afghanistan  2012.0  5.454545              NaN
# 3        Afghanistan  2011.0  5.000000              NaN
# 4        Afghanistan  2010.0  4.000000              NaN
# ...              ...     ...       ...              ...
# 4654             NaN     NaN       NaN              NaN
# 4655             NaN     NaN       NaN              NaN
# 4656             NaN     NaN       NaN              NaN
# 4657             NaN     NaN       NaN              NaN
# 4658             NaN     NaN       NaN              NaN
#
# [4659 rows x 4 columns]

# %% [markdown]
# 23. Drop the Value Footnotes column and then rename the columns to ‘Country’, ‘Year’, and ‘Internet_Users_Pct’.

# %%
internet_df= internet_df.iloc[:,:-1]

# %%
internet_df
# Out:
#      Country or Area    Year     Value
# 0        Afghanistan  2014.0  6.390000
# 1        Afghanistan  2013.0  5.900000
# 2        Afghanistan  2012.0  5.454545
# 3        Afghanistan  2011.0  5.000000
# 4        Afghanistan  2010.0  4.000000
# ...              ...     ...       ...
# 4654             NaN     NaN       NaN
# 4655             NaN     NaN       NaN
# 4656             NaN     NaN       NaN
# 4657             NaN     NaN       NaN
# 4658             NaN     NaN       NaN
#
# [4659 rows x 3 columns]

# %%
internet_df.dropna()
# Out:
#      Country or Area    Year     Value
# 0        Afghanistan  2014.0  6.390000
# 1        Afghanistan  2013.0  5.900000
# 2        Afghanistan  2012.0  5.454545
# 3        Afghanistan  2011.0  5.000000
# 4        Afghanistan  2010.0  4.000000
# ...              ...     ...       ...
# 4490        Zimbabwe  1997.0  0.033080
# 4491        Zimbabwe  1996.0  0.016790
# 4492        Zimbabwe  1995.0  0.007684
# 4493        Zimbabwe  1994.0  0.001739
# 4494        Zimbabwe  1990.0  0.000000
#
# [4495 rows x 3 columns]

# %%
internet_df=internet_df.rename(columns={'Country or Area':'Country', 'Year':'Year', 'Value':'Internet_Users_Pct'})

# %%
internet_df
# Out:
#           Country    Year  Internet_Users_Pct
# 0     Afghanistan  2014.0            6.390000
# 1     Afghanistan  2013.0            5.900000
# 2     Afghanistan  2012.0            5.454545
# 3     Afghanistan  2011.0            5.000000
# 4     Afghanistan  2010.0            4.000000
# ...           ...     ...                 ...
# 4654          NaN     NaN                 NaN
# 4655          NaN     NaN                 NaN
# 4656          NaN     NaN                 NaN
# 4657          NaN     NaN                 NaN
# 4658          NaN     NaN                 NaN
#
# [4659 rows x 3 columns]

# %%
internet_df= internet_df.dropna()

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4495 entries, 0 to 4494
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             4495 non-null   object
#  1   Year                4495 non-null   float64
#  2   Internet_Users_Pct  4495 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 140.5+ KB

# %% [markdown]
# 25. What is the first year that has a nonzero internet users percentage reported? What is the general trend in internet users percentage over the years. Pick a visualization that you think illustrates this trend well.

# %%
#internet_df.plot(y='Internet_Users_Pct', x='Year', kind='bar',title='Internet Users %')
#plt.xticks(rotation=90);

# %% [markdown]
# 26. Merge gdp_df and internet_df (on Country and Year) into a single DataFrame named gdp_and_internet_use. Keep only countries and years that appear in both tables

# %%
internet_df['Year']=internet_df['Year'].astype(int)
gdp_df['Year']=gdp_df['Year'].astype(int)
#internet_df['Year']=internet_df['Year'].astype(str)
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4495 entries, 0 to 4494
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             4495 non-null   object
#  1   Year                4495 non-null   int32
#  2   Internet_Users_Pct  4495 non-null   float64
# dtypes: float64(1), int32(1), object(1)
# memory usage: 122.9+ KB
# <ipython-input-67-b561d15aa3cd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   internet_df['Year']=internet_df['Year'].astype(int)

# %%
internet_df['Year'][0]
# Out:
# 2014

# %%
gdp_df['Year'][0]
# Out:
# 2019

# %%
gdp_and_internet_use=pd.merge(left = internet_df, 
         right = gdp_df, 
         left_on = ['Country','Year'], 
         right_on = ['Country','Year'])
gdp_and_internet_use
# Out:
#           Country  Year  Internet_Users_Pct Continent  GDP_Per_Capita
# 0     Afghanistan  2014            6.390000      Asia     2102.385234
# 1     Afghanistan  2013            5.900000      Asia     2116.465454
# 2     Afghanistan  2012            5.454545      Asia     2075.491747
# 3     Afghanistan  2011            5.000000      Asia     1904.559799
# 4     Afghanistan  2010            4.000000      Asia     1957.029338
# ...           ...   ...                 ...       ...             ...
# 3453     Zimbabwe  1997            0.033080    Africa     3580.048793
# 3454     Zimbabwe  1996            0.016790    Africa     3520.430146
# 3455     Zimbabwe  1995            0.007684    Africa     3226.413930
# 3456     Zimbabwe  1994            0.001739    Africa     3263.934978
# 3457     Zimbabwe  1990            0.000000    Africa     3324.348171
#
# [3458 rows x 5 columns]

# %% [markdown]
# 27.Look at the first five rows of your new data frame to confirm it merged correctly. Also, check the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use.tail(5)
# Out:
#        Country  Year  Internet_Users_Pct Continent  GDP_Per_Capita
# 3453  Zimbabwe  1997            0.033080    Africa     3580.048793
# 3454  Zimbabwe  1996            0.016790    Africa     3520.430146
# 3455  Zimbabwe  1995            0.007684    Africa     3226.413930
# 3456  Zimbabwe  1994            0.001739    Africa     3263.934978
# 3457  Zimbabwe  1990            0.000000    Africa     3324.348171

# %% [markdown]
# 28. Create a new DataFrame, named gdp_and_internet_use_2014 by extracting data for the year 2014 from gdp_and_internet_use. How many countries have at least 90% internet users in 2014?

# %%
gdp_and_internet_use_2014=gdp_and_internet_use[gdp_and_internet_use['Year']==2014]
gdp_and_internet_use_2014.head()
# Out:
#                 Country  Year  Internet_Users_Pct      Continent  \
# 0           Afghanistan  2014                6.39           Asia
# 13              Albania  2014               60.10         Europe
# 34              Algeria  2014               18.09         Africa
# 56               Angola  2014               21.26         Africa
# 76  Antigua and Barbuda  2014               64.00  North America
#
#     GDP_Per_Capita
# 0      2102.385234
# 13    11623.866679
# 34    11512.705405
# 56     8239.828837
# 76    18104.241470

# %%
gdp_and_internet_use_2014.sort_values('Internet_Users_Pct', ascending= False).head(10)
#How do I groupny with conditional statement:
#gdp_and_internet_use_2014.groupby('Country')['Internet_Users_Pct'>90]
# Out:
#              Country  Year  Internet_Users_Pct      Continent  GDP_Per_Capita
# 1381         Iceland  2014               98.16         Europe    49652.149500
# 372          Bermuda  2014               96.80  North America    77361.104881
# 2296          Norway  2014               96.30         Europe    62589.373548
# 854          Denmark  2014               95.99         Europe    52214.537753
# 1798      Luxembourg  2014               94.67         Europe   108760.916030
# 2185     Netherlands  2014               93.17         Europe    52353.666990
# 2975          Sweden  2014               92.52         Europe    49416.289877
# 1053         Finland  2014               92.38         Europe    45013.100455
# 3301  United Kingdom  2014               91.61         Europe    44209.510472
# 2542           Qatar  2014               91.49           Asia    95578.416973

# %% [markdown]
# 29.Find the countries that had the top 3 largest GDP per capita figures for 2014. Create a seaborn FacetGrid showing the change in internet user percentage over time for these three countries. Each individual figure in the facet grid will represent a single country. What trends do you notice?

# %%
top3=gdp_and_internet_use_2014.sort_values('GDP_Per_Capita', ascending=False).head(3)
top3
top3_all_years=gdp_and_internet_use[gdp_and_internet_use['Country'].isin(['Luxembourg','Qatar','Singapore'])]
top3_all_years
# Out:
#          Country  Year  Internet_Users_Pct Continent  GDP_Per_Capita
# 1798  Luxembourg  2014           94.670000    Europe   108760.916030
# 1799  Luxembourg  2013           93.776500    Europe   106767.275005
# 1800  Luxembourg  2012           91.949924    Europe   105411.464571
# 1801  Luxembourg  2011           90.029859    Europe   108355.582583
# 1802  Luxembourg  2010           90.620000    Europe   108047.346867
# ...          ...   ...                 ...       ...             ...
# 2771   Singapore  1994            1.185204      Asia    46895.053010
# 2772   Singapore  1993            0.763278      Asia    43555.619036
# 2773   Singapore  1992            0.471368      Asia    40077.548794
# 2774   Singapore  1991            0.161504      Asia    38728.403909
# 2775   Singapore  1990            0.000000      Asia    37348.206786
#
# [64 rows x 5 columns]

# %%
top3_all_years_graph=sns.FacetGrid(top3_all_years, col="Country")
top3_all_years_graph.map(plt.plot, "Year","Internet_Users_Pct")
plt.xticks(rotation=90);

# %% [markdown]
# 30. Create a scatter plot of Internet Use vs GDP per Capita for the year 2014. What do you notice?

# %%
gdp_and_internet_use_2014.plot(x="GDP_Per_Capita",y="Internet_Users_Pct", kind="scatter")
# Out:
# <AxesSubplot:xlabel='GDP_Per_Capita', ylabel='Internet_Users_Pct'>

# %% [markdown]
# 31.Find the correlation between GDP per Capita and Internet Use for the year 2014. What is the meaning of this number?

# %%
gdp_and_internet_use_2014.head()
# Out:
#                 Country  Year  Internet_Users_Pct      Continent  \
# 0           Afghanistan  2014                6.39           Asia
# 13              Albania  2014               60.10         Europe
# 34              Algeria  2014               18.09         Africa
# 56               Angola  2014               21.26         Africa
# 76  Antigua and Barbuda  2014               64.00  North America
#
#     GDP_Per_Capita
# 0      2102.385234
# 13    11623.866679
# 34    11512.705405
# 56     8239.828837
# 76    18104.241470

# %%
gdp_int_corr=gdp_and_internet_use_2014['GDP_Per_Capita'].corr(gdp_and_internet_use_2014['Internet_Users_Pct'])
gdp_int_corr
# Out:
# 0.8246267227541505

# %% [markdown]
# 32.Add a column to gdp_and_internet_use_2014 and calculate the logarithm of GDP per capita. Find the correlation between the log of GDP per capita and internet users percentage. How does this compare to the calculation in the previous part?

# %%
gdp_and_internet_use_2014['log of GDP_Per_Capita'] ="Z"
# Out:
# <ipython-input-79-4490401820c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_and_internet_use_2014['log of GDP_Per_Capita'] ="Z"

# %%
gdp_and_internet_use_2014['log of GDP_Per_Capita']=np.log(gdp_and_internet_use_2014['GDP_Per_Capita'])
gdp_and_internet_use_2014.head()
# Out:
# <ipython-input-80-4501b18b066c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdp_and_internet_use_2014['log of GDP_Per_Capita']=np.log(gdp_and_internet_use_2014['GDP_Per_Capita'])
#                 Country  Year  Internet_Users_Pct      Continent  \
# 0           Afghanistan  2014                6.39           Asia
# 13              Albania  2014               60.10         Europe
# 34              Algeria  2014               18.09         Africa
# 56               Angola  2014               21.26         Africa
# 76  Antigua and Barbuda  2014               64.00  North America
#
#     GDP_Per_Capita  log of GDP_Per_Capita
# 0      2102.385234               7.650828
# 13    11623.866679               9.360816
# ...

# %%
gdp_log_int_corr=gdp_and_internet_use_2014['log of GDP_Per_Capita'].corr(gdp_and_internet_use_2014['Internet_Users_Pct'])
gdp_log_int_corr
# Out:
# 0.903986635681392

# %% [markdown]
# correlation between log GDP & Internet_Pct is stronger than correlation between GDP & Int_Pct (the difference in values is smaller)

# %%
top3_all_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 1798 to 2775
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             64 non-null     object
#  1   Year                64 non-null     int32
#  2   Internet_Users_Pct  64 non-null     float64
#  3   Continent           64 non-null     object
#  4   GDP_Per_Capita      64 non-null     float64
# dtypes: float64(2), int32(1), object(2)
# memory usage: 2.8+ KB

# %%
gdp_df.tail()
# Out:
#      Continent   Country  Year  GDP_Per_Capita
# 5438    Africa  Zimbabwe  1994     3263.934978
# 5439    Africa  Zimbabwe  1993     3033.504852
# 5440    Africa  Zimbabwe  1992     3054.889178
# 5441    Africa  Zimbabwe  1991     3426.598094
# 5442    Africa  Zimbabwe  1990     3324.348171

# %%
internet_df.tail()
# Out:
#        Country  Year  Internet_Users_Pct
# 4490  Zimbabwe  1997            0.033080
# 4491  Zimbabwe  1996            0.016790
# 4492  Zimbabwe  1995            0.007684
# 4493  Zimbabwe  1994            0.001739
# 4494  Zimbabwe  1990            0.000000

# %%
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5443 entries, 0 to 5442
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Continent       5443 non-null   object
#  1   Country         5443 non-null   object
#  2   Year            5443 non-null   int32
#  3   GDP_Per_Capita  5443 non-null   float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 320.4+ KB

# %%
gdp_and_internet_use_2014.columns
# Out:
# Index(['Country', 'Year', 'Internet_Users_Pct', 'Continent', 'GDP_Per_Capita',
#        'log of GDP_Per_Capita'],
#       dtype='object')

# %% [markdown]
# 33. Filter the original dataset down to just the United States for all available years. Calculate correlation between internet use and gdp per capita. Is this meaningful or useful?

# %%
gdp_and_internet_use[gdp_and_internet_use['Country']=='United States']
US_gdp_int_corr=gdp_and_internet_use['GDP_Per_Capita'].corr(gdp_and_internet_use['Internet_Users_Pct'])
US_gdp_int_corr
# Out:
# 0.6205048804078838
